# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from pathlib import Path
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Get the nearest city using the citipy module.


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
   
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fortuna
# Processing Record 2 of Set 1 | kruisfontein
# Processing Record 3 of Set 1 | qui nhon
# Processing Record 4 of Set 1 | zhob
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | miraflores
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | lasa
# Processing Record 13 of Set 1 | warangal
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | san jose
# Processing Record 18 of Set 1 | havre-saint-pierre
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | winnemucca
# Processing Record 21 of Set 1 | camacha
# Processing Record 22 of Set 1 | fort payne
# Processing Record 23 of Set 1 | meulaboh
# Processing Record 24 of Set 1 | guerrero negro
# Processing Record 25 of Set 1 | salisbury
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | bandarbeyla
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | cockburn town
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | slyudyanka
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | sakakah
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | staryy nadym
# Processing Record 46 of Set 1 | ulaangom
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | mehamn
# Processing Record 49 of Set 1 | trairi
# Processing Record 50 of Set 1 | itea
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | praya
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | awbari
# Processing Record 5 of Set 2 | guangyuan
# Processing Record 6 of Set 2 | high rock
# Processing Record 7 of Set 2 | fairbanks
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 2 | troitskaya
# Processing Record 11 of Set 2 | elko
# Processing Record 12 of Set 2 | nong khae
# Processing Record 13 of Set 2 | lavrentiya
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | mkushi
# Processing Record 16 of Set 2 | talnakh
# Processing Record 17 of Set 2 | bilma
# Processing Record 18 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | pombia
# Processing Record 21 of Set 2 | abonnema
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 2 | fort morgan
# Processing Record 25 of Set 2 | bani walid
# Processing Record 26 of Set 2 | kushiro
# Processing Record 27 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | alice springs
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | natal
# Processing Record 35 of Set 2 | tiarei
# Processing Record 36 of Set 2 | burica
# City not found. Skipping...
# Processing Record 37 of Set 2 | peachland
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | banda aceh
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | lata
# Processing Record 42 of Set 2 | itoman
# Processing Record 43 of Set 2 | catamarca
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | rasht
# Processing Record 48 of Set 2 | chinsali
# Processing Record 49 of Set 2 | watertown
# Processing Record 50 of Set 2 | albany
# Processing Record 1 of Set 3 | fatikchhari
# City not found. Skipping...
# Processing Record 2 of Set 3 | port blair
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | neiafu
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | rocha
# Processing Record 8 of Set 3 | san lawrenz
# Processing Record 9 of Set 3 | mulchen
# Processing Record 10 of Set 3 | gigmoto
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 3 | shelburne
# Processing Record 14 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 3 | rio gallegos
# Processing Record 16 of Set 3 | praia da vitoria
# Processing Record 17 of Set 3 | piacabucu
# Processing Record 18 of Set 3 | praia
# Processing Record 19 of Set 3 | bazarnyye mataki
# Processing Record 20 of Set 3 | tiznit
# Processing Record 21 of Set 3 | kevsala
# Processing Record 22 of Set 3 | acari
# Processing Record 23 of Set 3 | kahului
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | bathsheba
# Processing Record 26 of Set 3 | barcelos
# Processing Record 27 of Set 3 | sovetskiy
# Processing Record 28 of Set 3 | pilar
# Processing Record 29 of Set 3 | atar
# Processing Record 30 of Set 3 | hofn
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | rudnyy
# Processing Record 36 of Set 3 | shache
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | korla
# Processing Record 39 of Set 3 | miandrivazo
# Processing Record 40 of Set 3 | komsomolskiy
# Processing Record 41 of Set 3 | itarema
# Processing Record 42 of Set 3 | palmer
# Processing Record 43 of Set 3 | samarai
# Processing Record 44 of Set 3 | acapulco
# Processing Record 45 of Set 3 | san ramon
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | burnie
# Processing Record 48 of Set 3 | bichena
# Processing Record 49 of Set 3 | krasnovishersk
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | mukhen
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | pandan
# Processing Record 4 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | axim
# Processing Record 6 of Set 4 | road town
# Processing Record 7 of Set 4 | peterhead
# Processing Record 8 of Set 4 | new smyrna beach
# Processing Record 9 of Set 4 | mlowo
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 4 | najran
# Processing Record 13 of Set 4 | shimoda
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | edd
# Processing Record 16 of Set 4 | henties bay
# Processing Record 17 of Set 4 | rumphi
# Processing Record 18 of Set 4 | ketchikan
# Processing Record 19 of Set 4 | lakeside
# Processing Record 20 of Set 4 | yatou
# Processing Record 21 of Set 4 | caravelas
# Processing Record 22 of Set 4 | haines junction
# Processing Record 23 of Set 4 | canton
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | isangel
# Processing Record 27 of Set 4 | kodiak
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | patrasaer
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | hearst
# Processing Record 32 of Set 4 | leshukonskoye
# Processing Record 33 of Set 4 | lumeje
# Processing Record 34 of Set 4 | arrecife
# Processing Record 35 of Set 4 | madimba
# Processing Record 36 of Set 4 | sao filipe
# Processing Record 37 of Set 4 | kununurra
# Processing Record 38 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 4 | telemaco borba
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | narrabri
# Processing Record 43 of Set 4 | kadiri
# Processing Record 44 of Set 4 | pumiao
# Processing Record 45 of Set 4 | richards bay
# Processing Record 46 of Set 4 | pundaguitan
# Processing Record 47 of Set 4 | sapa
# Processing Record 48 of Set 4 | baykit
# Processing Record 49 of Set 4 | hirara
# Processing Record 50 of Set 4 | owasso
# Processing Record 1 of Set 5 | isla vista
# Processing Record 2 of Set 5 | muli
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | japura
# Processing Record 6 of Set 5 | luderitz
# Processing Record 7 of Set 5 | hithadhoo
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | arkhara
# Processing Record 11 of Set 5 | ostrovnoy
# Processing Record 12 of Set 5 | pontes e lacerda
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | ambalavao
# Processing Record 15 of Set 5 | wageningen
# Processing Record 16 of Set 5 | clarence town
# Processing Record 17 of Set 5 | awjilah
# Processing Record 18 of Set 5 | ilhabela
# Processing Record 19 of Set 5 | trinidad
# Processing Record 20 of Set 5 | norman wells
# Processing Record 21 of Set 5 | ilulissat
# Processing Record 22 of Set 5 | atambua
# Processing Record 23 of Set 5 | calama
# Processing Record 24 of Set 5 | auckland
# Processing Record 25 of Set 5 | sanjwal
# Processing Record 26 of Set 5 | lagos
# Processing Record 27 of Set 5 | lazaro cardenas
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | yumen
# Processing Record 30 of Set 5 | chokurdakh
# Processing Record 31 of Set 5 | porto novo
# Processing Record 32 of Set 5 | dhing
# Processing Record 33 of Set 5 | bocas del toro
# Processing Record 34 of Set 5 | taoudenni
# Processing Record 35 of Set 5 | chara
# Processing Record 36 of Set 5 | boundiali
# Processing Record 37 of Set 5 | lamar
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | barraute
# Processing Record 40 of Set 5 | matara
# Processing Record 41 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 5 | goderich
# Processing Record 43 of Set 5 | port-gentil
# Processing Record 44 of Set 5 | los llanos de aridane
# Processing Record 45 of Set 5 | mao
# Processing Record 46 of Set 5 | amarante do maranhao
# Processing Record 47 of Set 5 | bambanglipuro
# Processing Record 48 of Set 5 | broome
# Processing Record 49 of Set 5 | alofi
# Processing Record 50 of Set 5 | vilhena
# Processing Record 1 of Set 6 | chumikan
# Processing Record 2 of Set 6 | ambon
# Processing Record 3 of Set 6 | tamandare
# Processing Record 4 of Set 6 | alton
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | victoria
# Processing Record 7 of Set 6 | jumla
# Processing Record 8 of Set 6 | bettiah
# Processing Record 9 of Set 6 | ribeira grande
# Processing Record 10 of Set 6 | stepnyak
# Processing Record 11 of Set 6 | nelson
# Processing Record 12 of Set 6 | severnyy
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | charlotte
# Processing Record 16 of Set 6 | mumford
# Processing Record 17 of Set 6 | portland
# Processing Record 18 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 6 | talara
# Processing Record 20 of Set 6 | severomuysk
# Processing Record 21 of Set 6 | tutoia
# Processing Record 22 of Set 6 | kaitangata
# Processing Record 23 of Set 6 | arraial do cabo
# Processing Record 24 of Set 6 | asau
# Processing Record 25 of Set 6 | nioro
# Processing Record 26 of Set 6 | tshikapa
# Processing Record 27 of Set 6 | kedgwick
# Processing Record 28 of Set 6 | pehowa
# Processing Record 29 of Set 6 | skibbereen
# Processing Record 30 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 31 of Set 6 | tongren
# Processing Record 32 of Set 6 | mashhad
# Processing Record 33 of Set 6 | manyana
# Processing Record 34 of Set 6 | belyy yar
# Processing Record 35 of Set 6 | monster
# Processing Record 36 of Set 6 | yarada
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | kabo
# Processing Record 39 of Set 6 | katsuura
# Processing Record 40 of Set 6 | sangar
# Processing Record 41 of Set 6 | mutsu
# Processing Record 42 of Set 6 | hay river
# Processing Record 43 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 6 | kaili
# Processing Record 45 of Set 6 | san patricio
# Processing Record 46 of Set 6 | tilichiki
# Processing Record 47 of Set 6 | iwanai
# Processing Record 48 of Set 6 | marquette
# Processing Record 49 of Set 6 | muros
# Processing Record 50 of Set 6 | vila velha
# Processing Record 1 of Set 7 | nuuk
# Processing Record 2 of Set 7 | hermosillo
# Processing Record 3 of Set 7 | zhangye
# Processing Record 4 of Set 7 | sainte-rose
# Processing Record 5 of Set 7 | xenia
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 7 | mutoko
# Processing Record 9 of Set 7 | sao lourenco do oeste
# Processing Record 10 of Set 7 | mar del plata
# Processing Record 11 of Set 7 | carmen
# Processing Record 12 of Set 7 | verkhnyaya toyma
# Processing Record 13 of Set 7 | bambous virieux
# Processing Record 14 of Set 7 | terney
# Processing Record 15 of Set 7 | esperance
# Processing Record 16 of Set 7 | treinta y tres
# Processing Record 17 of Set 7 | rudnichnyy
# Processing Record 18 of Set 7 | coxim
# Processing Record 19 of Set 7 | maldonado
# Processing Record 20 of Set 7 | ponta do sol
# Processing Record 21 of Set 7 | desnogorsk
# Processing Record 22 of Set 7 | raudeberg
# Processing Record 23 of Set 7 | gimli
# Processing Record 24 of Set 7 | san benedetto del tronto
# Processing Record 25 of Set 7 | tuktoyaktuk
# Processing Record 26 of Set 7 | saskylakh
# Processing Record 27 of Set 7 | barra do garcas
# Processing Record 28 of Set 7 | canaries
# Processing Record 29 of Set 7 | russkaya polyana
# Processing Record 30 of Set 7 | kasongo-lunda
# Processing Record 31 of Set 7 | billings
# Processing Record 32 of Set 7 | nichinan
# Processing Record 33 of Set 7 | mamallapuram
# Processing Record 34 of Set 7 | gidole
# Processing Record 35 of Set 7 | sitka
# Processing Record 36 of Set 7 | solnechnyy
# Processing Record 37 of Set 7 | caorle
# Processing Record 38 of Set 7 | oyem
# Processing Record 39 of Set 7 | quatre cocos
# Processing Record 40 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 41 of Set 7 | dudinka
# Processing Record 42 of Set 7 | namibe
# Processing Record 43 of Set 7 | prado
# Processing Record 44 of Set 7 | oga
# Processing Record 45 of Set 7 | xuanwu
# Processing Record 46 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 7 | cintalapa
# Processing Record 48 of Set 7 | eyl
# Processing Record 49 of Set 7 | margate
# Processing Record 50 of Set 7 | santa maria
# Processing Record 1 of Set 8 | churapcha
# Processing Record 2 of Set 8 | nizhniy kuranakh
# Processing Record 3 of Set 8 | general roca
# Processing Record 4 of Set 8 | praxedis guerrero
# Processing Record 5 of Set 8 | dom pedrito
# Processing Record 6 of Set 8 | singarayakonda
# Processing Record 7 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 8 of Set 8 | dolores
# Processing Record 9 of Set 8 | vanimo
# Processing Record 10 of Set 8 | port hedland
# Processing Record 11 of Set 8 | saint-prosper
# Processing Record 12 of Set 8 | gat
# Processing Record 13 of Set 8 | muscatine
# Processing Record 14 of Set 8 | asfi
# Processing Record 15 of Set 8 | lokoja
# Processing Record 16 of Set 8 | hambantota
# Processing Record 17 of Set 8 | voi
# Processing Record 18 of Set 8 | poya
# Processing Record 19 of Set 8 | bredasdorp
# Processing Record 20 of Set 8 | prieska
# Processing Record 21 of Set 8 | la ronge
# Processing Record 22 of Set 8 | ugoofaaru
# Processing Record 23 of Set 8 | leningradskiy
# Processing Record 24 of Set 8 | bar harbor
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | belmonte
# Processing Record 27 of Set 8 | gisborne
# Processing Record 28 of Set 8 | grand gaube
# Processing Record 29 of Set 8 | kupang
# Processing Record 30 of Set 8 | tunceli
# Processing Record 31 of Set 8 | saldanha
# Processing Record 32 of Set 8 | ghanzi
# Processing Record 33 of Set 8 | tungor
# Processing Record 34 of Set 8 | tura
# Processing Record 35 of Set 8 | port augusta
# Processing Record 36 of Set 8 | begichevskiy
# Processing Record 37 of Set 8 | dubbo
# Processing Record 38 of Set 8 | walvis bay
# Processing Record 39 of Set 8 | atasu
# Processing Record 40 of Set 8 | mahajanga
# Processing Record 41 of Set 8 | dunedin
# Processing Record 42 of Set 8 | kavaratti
# Processing Record 43 of Set 8 | la grande
# Processing Record 44 of Set 8 | harper
# Processing Record 45 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 8 | merauke
# Processing Record 47 of Set 8 | katima mulilo
# Processing Record 48 of Set 8 | maragogi
# Processing Record 49 of Set 8 | gladstone
# Processing Record 50 of Set 8 | soria
# Processing Record 1 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 9 | toamasina
# Processing Record 5 of Set 9 | pacific grove
# Processing Record 6 of Set 9 | moree
# Processing Record 7 of Set 9 | chapais
# Processing Record 8 of Set 9 | gravdal
# Processing Record 9 of Set 9 | sochi
# Processing Record 10 of Set 9 | magnolia
# Processing Record 11 of Set 9 | kjollefjord
# Processing Record 12 of Set 9 | opuwo
# Processing Record 13 of Set 9 | jacareacanga
# Processing Record 14 of Set 9 | mbala
# Processing Record 15 of Set 9 | hami
# Processing Record 16 of Set 9 | puerto escondido
# Processing Record 17 of Set 9 | tyukhtet
# Processing Record 18 of Set 9 | yulara
# Processing Record 19 of Set 9 | nabire
# Processing Record 20 of Set 9 | avera
# Processing Record 21 of Set 9 | kieta
# Processing Record 22 of Set 9 | yashkul
# Processing Record 23 of Set 9 | marienburg
# Processing Record 24 of Set 9 | cam ranh
# Processing Record 25 of Set 9 | northam
# Processing Record 26 of Set 9 | morondava
# Processing Record 27 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 9 | polczyn-zdroj
# Processing Record 29 of Set 9 | north bend
# Processing Record 30 of Set 9 | teguldet
# Processing Record 31 of Set 9 | kirakira
# Processing Record 32 of Set 9 | anqing
# Processing Record 33 of Set 9 | ahuimanu
# Processing Record 34 of Set 9 | homer
# Processing Record 35 of Set 9 | tuatapere
# Processing Record 36 of Set 9 | sinnamary
# Processing Record 37 of Set 9 | urengoy
# Processing Record 38 of Set 9 | kelo
# Processing Record 39 of Set 9 | bolshaya vishera
# City not found. Skipping...
# Processing Record 40 of Set 9 | narsaq
# Processing Record 41 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 9 | port lincoln
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | iberia
# Processing Record 45 of Set 9 | ixtapa
# Processing Record 46 of Set 9 | zuenoula
# Processing Record 47 of Set 9 | hasaki
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | srandakan
# Processing Record 50 of Set 9 | tateyama
# Processing Record 1 of Set 10 | landshut
# Processing Record 2 of Set 10 | chunskiy
# Processing Record 3 of Set 10 | kankon
# Processing Record 4 of Set 10 | moron
# Processing Record 5 of Set 10 | seydi
# Processing Record 6 of Set 10 | pervoye maya
# Processing Record 7 of Set 10 | dulce grande
# Processing Record 8 of Set 10 | lodja
# Processing Record 9 of Set 10 | cadereyta
# Processing Record 10 of Set 10 | rabo de peixe
# Processing Record 11 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 12 of Set 10 | ust-koksa
# Processing Record 13 of Set 10 | pangnirtung
# Processing Record 14 of Set 10 | flin flon
# Processing Record 15 of Set 10 | sayat
# Processing Record 16 of Set 10 | coelho neto
# Processing Record 17 of Set 10 | naze
# Processing Record 18 of Set 10 | borogontsy
# Processing Record 19 of Set 10 | marawi
# Processing Record 20 of Set 10 | dolinsk
# Processing Record 21 of Set 10 | sumbe
# Processing Record 22 of Set 10 | felanitx
# Processing Record 23 of Set 10 | kamaishi
# Processing Record 24 of Set 10 | de aar
# Processing Record 25 of Set 10 | karabash
# Processing Record 26 of Set 10 | cascais
# Processing Record 27 of Set 10 | stornoway
# Processing Record 28 of Set 10 | verkhnevilyuysk
# Processing Record 29 of Set 10 | nebolchi
# Processing Record 30 of Set 10 | warri
# Processing Record 31 of Set 10 | touros
# Processing Record 32 of Set 10 | carbonia
# Processing Record 33 of Set 10 | quelimane
# Processing Record 34 of Set 10 | gavrilovka vtoraya
# Processing Record 35 of Set 10 | bubaque
# Processing Record 36 of Set 10 | antofagasta
# Processing Record 37 of Set 10 | parabel
# Processing Record 38 of Set 10 | santa cruz del sur
# Processing Record 39 of Set 10 | ishigaki
# Processing Record 40 of Set 10 | gornyak
# Processing Record 41 of Set 10 | ayan
# Processing Record 42 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 43 of Set 10 | kuandian
# Processing Record 44 of Set 10 | angoche
# Processing Record 45 of Set 10 | lar gerd
# City not found. Skipping...
# Processing Record 46 of Set 10 | aykhal
# Processing Record 47 of Set 10 | paris
# Processing Record 48 of Set 10 | we
# City not found. Skipping...
# Processing Record 49 of Set 10 | lompoc
# Processing Record 50 of Set 10 | karratha
# Processing Record 1 of Set 11 | umea
# Processing Record 2 of Set 11 | gari
# Processing Record 3 of Set 11 | coari
# Processing Record 4 of Set 11 | yangcun
# Processing Record 5 of Set 11 | iralaya
# Processing Record 6 of Set 11 | jibuti
# Processing Record 7 of Set 11 | sulphur
# Processing Record 8 of Set 11 | yar-sale
# Processing Record 9 of Set 11 | nantucket
# Processing Record 10 of Set 11 | auki
# Processing Record 11 of Set 11 | corum
# Processing Record 12 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 11 | gorbehaza
# Processing Record 15 of Set 11 | kota bahru
# Processing Record 16 of Set 11 | the valley
# Processing Record 17 of Set 11 | vardo
# Processing Record 18 of Set 11 | beyneu
# Processing Record 19 of Set 11 | bacungan
# Processing Record 20 of Set 11 | letlhakane
# Processing Record 21 of Set 11 | anjiang
# Processing Record 22 of Set 11 | petropavlovka
# Processing Record 23 of Set 11 | pisco
# Processing Record 24 of Set 11 | north battleford
# Processing Record 25 of Set 11 | pangoa
# Processing Record 26 of Set 11 | lorengau
# Processing Record 27 of Set 11 | dawson creek
# Processing Record 28 of Set 11 | launceston
# Processing Record 29 of Set 11 | bereda
# Processing Record 30 of Set 11 | diamantino
# Processing Record 31 of Set 11 | khorinsk
# Processing Record 32 of Set 11 | pamanukan
# Processing Record 33 of Set 11 | vestmannaeyjar
# Processing Record 34 of Set 11 | ust-kut
# Processing Record 35 of Set 11 | kuchaman
# Processing Record 36 of Set 11 | oktyabrskoye
# Processing Record 37 of Set 11 | ust-kuyga
# Processing Record 38 of Set 11 | doha
# Processing Record 39 of Set 11 | saint george
# Processing Record 40 of Set 11 | gambela
# Processing Record 41 of Set 11 | abu dhabi
# Processing Record 42 of Set 11 | kulhudhuffushi
# Processing Record 43 of Set 11 | lakatoro
# Processing Record 44 of Set 11 | qobustan
# Processing Record 45 of Set 11 | arawa
# Processing Record 46 of Set 11 | okha
# Processing Record 47 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 48 of Set 11 | soyo
# Processing Record 49 of Set 11 | khanpur
# Processing Record 50 of Set 11 | mayumba
# Processing Record 1 of Set 12 | lundazi
# Processing Record 2 of Set 12 | kawalu
# Processing Record 3 of Set 12 | garissa
# Processing Record 4 of Set 12 | aden
# Processing Record 5 of Set 12 | motygino
# Processing Record 6 of Set 12 | greensburg
# Processing Record 7 of Set 12 | eirunepe
# Processing Record 8 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 9 of Set 12 | banff
# Processing Record 10 of Set 12 | omsukchan
# Processing Record 11 of Set 12 | zhigansk
# Processing Record 12 of Set 12 | tabas
# Processing Record 13 of Set 12 | trincomalee
# Processing Record 14 of Set 12 | husavik
# Processing Record 15 of Set 12 | cap malheureux
# Processing Record 16 of Set 12 | oktyabrskiy
# Processing Record 17 of Set 12 | daru
# Processing Record 18 of Set 12 | uri
# Processing Record 19 of Set 12 | xingyi
# Processing Record 20 of Set 12 | poum
# Processing Record 21 of Set 12 | maniitsoq
# Processing Record 22 of Set 12 | makakilo city
# Processing Record 23 of Set 12 | tommot
# Processing Record 24 of Set 12 | dongkan
# Processing Record 25 of Set 12 | krasnoselkup
# Processing Record 26 of Set 12 | mogadishu
# Processing Record 27 of Set 12 | quixeramobim
# Processing Record 28 of Set 12 | mnogovershinnyy
# Processing Record 29 of Set 12 | stabat
# Processing Record 30 of Set 12 | da lat
# Processing Record 31 of Set 12 | lohardaga
# Processing Record 32 of Set 12 | leh
# Processing Record 33 of Set 12 | socoltenango
# Processing Record 34 of Set 12 | russell
# Processing Record 35 of Set 12 | arica
# Processing Record 36 of Set 12 | namtsy
# Processing Record 37 of Set 12 | otradnoye
# Processing Record 38 of Set 12 | ballina
# Processing Record 39 of Set 12 | qurayyat
# Processing Record 40 of Set 12 | zambezi
# Processing Record 41 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 12 | kokopo
# Processing Record 43 of Set 12 | porto velho
# Processing Record 44 of Set 12 | lovozero
# Processing Record 45 of Set 12 | tubmanburg
# Processing Record 46 of Set 12 | lamentin
# Processing Record 47 of Set 12 | aksu
# Processing Record 48 of Set 12 | sungairaya
# Processing Record 49 of Set 12 | zhanaozen
# Processing Record 50 of Set 12 | morant bay
# Processing Record 1 of Set 13 | rorvik
# Processing Record 2 of Set 13 | adrar
# Processing Record 3 of Set 13 | taltal
# Processing Record 4 of Set 13 | maine-soroa
# Processing Record 5 of Set 13 | tra vinh
# Processing Record 6 of Set 13 | troitsko-pechorsk
# Processing Record 7 of Set 13 | sao raimundo nonato
# Processing Record 8 of Set 13 | rocky mountain house
# Processing Record 9 of Set 13 | sola
# Processing Record 10 of Set 13 | ulaanbaatar
# Processing Record 11 of Set 13 | chihuahua
# Processing Record 12 of Set 13 | manicore
# Processing Record 13 of Set 13 | shiringushi
# Processing Record 14 of Set 13 | vanavara
# Processing Record 15 of Set 13 | trat
# Processing Record 16 of Set 13 | mount pleasant
# Processing Record 17 of Set 13 | kholtoson
# Processing Record 18 of Set 13 | camopi
# Processing Record 19 of Set 13 | sawakin
# Processing Record 20 of Set 13 | magdalena
# Processing Record 21 of Set 13 | sosnovo-ozerskoye
# Processing Record 22 of Set 13 | carutapera
# Processing Record 23 of Set 13 | ginda
# Processing Record 24 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 13 | bundaberg
# Processing Record 26 of Set 13 | padang
# Processing Record 27 of Set 13 | emilio carranza
# Processing Record 28 of Set 13 | bodden town
# Processing Record 29 of Set 13 | oranjemund
# Processing Record 30 of Set 13 | albury
# Processing Record 31 of Set 13 | porbandar
# Processing Record 32 of Set 13 | harker heights
# Processing Record 33 of Set 13 | rosetta
# Processing Record 34 of Set 13 | suluova
# Processing Record 35 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 13 | coalcoman
# City not found. Skipping...
# Processing Record 37 of Set 13 | sur
# Processing Record 38 of Set 13 | fort smith
# Processing Record 39 of Set 13 | puerto ayacucho
# Processing Record 40 of Set 13 | champerico
# Processing Record 41 of Set 13 | vila
# Processing Record 42 of Set 13 | fort nelson
# Processing Record 43 of Set 13 | digby
# Processing Record 44 of Set 13 | katobu
# Processing Record 45 of Set 13 | darhan
# Processing Record 46 of Set 13 | bonavista
# Processing Record 47 of Set 13 | vila franca do campo
# Processing Record 48 of Set 13 | sawtell
# Processing Record 49 of Set 13 | togur
# Processing Record 50 of Set 13 | dhrangadhra
# Processing Record 1 of Set 14 | ponta delgada
# Processing Record 2 of Set 14 | oxelosund
# Processing Record 3 of Set 14 | galyugayevskaya
# Processing Record 4 of Set 14 | tomatlan
# Processing Record 5 of Set 14 | inhambane
# Processing Record 6 of Set 14 | muscat
# Processing Record 7 of Set 14 | nelson bay
# Processing Record 8 of Set 14 | mana
# Processing Record 9 of Set 14 | buin
# Processing Record 10 of Set 14 | pasighat
# Processing Record 11 of Set 14 | port hawkesbury
# Processing Record 12 of Set 14 | tautira
# Processing Record 13 of Set 14 | novyy urgal
# Processing Record 14 of Set 14 | nguruka
# Processing Record 15 of Set 14 | mareeba
# Processing Record 16 of Set 14 | srednekolymsk
# Processing Record 17 of Set 14 | heishan
# Processing Record 18 of Set 14 | katangli
# Processing Record 19 of Set 14 | tonantins
# Processing Record 20 of Set 14 | aktas
# Processing Record 21 of Set 14 | coihaique
# Processing Record 22 of Set 14 | orlik
# Processing Record 23 of Set 14 | tekeli
# Processing Record 24 of Set 14 | cabra
# Processing Record 25 of Set 14 | laminusa
# Processing Record 26 of Set 14 | half moon bay
# Processing Record 27 of Set 14 | valparaiso
# Processing Record 28 of Set 14 | deputatskiy
# Processing Record 29 of Set 14 | calbuco
# Processing Record 30 of Set 14 | fort pierce
# Processing Record 31 of Set 14 | saint-pierre
# Processing Record 32 of Set 14 | centralia
# Processing Record 33 of Set 14 | kassala
# Processing Record 34 of Set 14 | biak
# Processing Record 35 of Set 14 | vao
# Processing Record 36 of Set 14 | roma
# Processing Record 37 of Set 14 | porgera
# Processing Record 38 of Set 14 | muzhi
# Processing Record 39 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | kursavka
# Processing Record 41 of Set 14 | roald
# Processing Record 42 of Set 14 | jalu
# Processing Record 43 of Set 14 | salinopolis
# Processing Record 44 of Set 14 | gobabis
# Processing Record 45 of Set 14 | udachnyy
# Processing Record 46 of Set 14 | oussouye
# Processing Record 47 of Set 14 | namatanai
# Processing Record 48 of Set 14 | mount isa
# Processing Record 49 of Set 14 | shenjiamen
# Processing Record 50 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 15 | kainantu
# Processing Record 2 of Set 15 | umm nuwarah
# City not found. Skipping...
# Processing Record 3 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 15 | port hardy
# Processing Record 5 of Set 15 | pampa
# Processing Record 6 of Set 15 | khingansk
# Processing Record 7 of Set 15 | suntar
# Processing Record 8 of Set 15 | kungurtug
# Processing Record 9 of Set 15 | dingle
# Processing Record 10 of Set 15 | buala
# Processing Record 11 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 15 | bilibino
# Processing Record 13 of Set 15 | santana do acarau
# Processing Record 14 of Set 15 | sao joao da barra
# Processing Record 15 of Set 15 | fershampenuaz
# Processing Record 16 of Set 15 | mgandu
# Processing Record 17 of Set 15 | lithakia
# Processing Record 18 of Set 15 | honningsvag
# Processing Record 19 of Set 15 | oistins
# Processing Record 20 of Set 15 | fuerte olimpo
# Processing Record 21 of Set 15 | paracuru
# Processing Record 22 of Set 15 | dhidhdhoo
# Processing Record 23 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 15 | belaya gora
# Processing Record 25 of Set 15 | cortez
# Processing Record 26 of Set 15 | xuddur
# Processing Record 27 of Set 15 | hobyo
# Processing Record 28 of Set 15 | yeppoon
# Processing Record 29 of Set 15 | kargasok
# Processing Record 30 of Set 15 | turan
# Processing Record 31 of Set 15 | nicoya
# Processing Record 32 of Set 15 | san cristobal
# Processing Record 33 of Set 15 | boende
# Processing Record 34 of Set 15 | novaya igirma
# Processing Record 35 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 36 of Set 15 | mtwara
# Processing Record 37 of Set 15 | simao
# Processing Record 38 of Set 15 | olafsvik
# Processing Record 39 of Set 15 | xining
# Processing Record 40 of Set 15 | mungeli
# Processing Record 41 of Set 15 | nekhayevskiy
# Processing Record 42 of Set 15 | sobolevo
# Processing Record 43 of Set 15 | astoria
# Processing Record 44 of Set 15 | yantal
# Processing Record 45 of Set 15 | mackay
# Processing Record 46 of Set 15 | pacifica
# Processing Record 47 of Set 15 | podgornoye
# Processing Record 48 of Set 15 | abu samrah
# Processing Record 49 of Set 15 | kaka
# Processing Record 50 of Set 15 | sibsagar
# Processing Record 1 of Set 16 | huilong
# Processing Record 2 of Set 16 | milledgeville
# Processing Record 3 of Set 16 | paraiso
# Processing Record 4 of Set 16 | aranda de duero
# Processing Record 5 of Set 16 | polewali
# Processing Record 6 of Set 16 | lerwick
# Processing Record 7 of Set 16 | berat
# Processing Record 8 of Set 16 | netarhat
# Processing Record 9 of Set 16 | bud
# Processing Record 10 of Set 16 | karlskoga
# Processing Record 11 of Set 16 | mabaruma
# Processing Record 12 of Set 16 | sibu
# Processing Record 13 of Set 16 | cananea
# Processing Record 14 of Set 16 | nara
# Processing Record 15 of Set 16 | cairns
# Processing Record 16 of Set 16 | san jeronimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Fortuna  40.5982 -124.1573     69.93           clear sky        79
# 1  Kruisfontein -34.0033   24.7314     53.89           clear sky        81
# 2      Qui Nhon  13.7667  109.2333     78.26           clear sky        87
# 3          Zhob  31.3411   69.4481     74.97           clear sky        58
# 4        Barrow  71.2906 -156.7887     39.22                mist        93
# 5       Qaanaaq  77.4840  -69.3632     31.82           clear sky        68
# 6      Thompson  55.7435  -97.8558     57.43     overcast clouds        47
# 7     Jamestown  42.0970  -79.2353     73.02          few clouds        49
# 8    Miraflores  19.2167  -98.8083     77.65     overcast clouds        74
# 9       Kavieng  -2.5744  150.7967     84.61     overcast clouds        64
#
#    Cloudiness  Wind Speed Country                 Date
# 0           0       13.80      US  2022-08-31 23:06:02
# 1           0        7.47      ZA  2022-08-31 23:06:03
# 2           0        4.21      VN  2022-08-31 23:06:04
# 3           0        4.12      PK  2022-08-31 23:06:04
# 4         100       23.02      US  2022-08-31 23:06:05
# 5           0        3.18      GL  2022-08-31 23:02:44
# 6          98        3.40      CA  2022-08-31 23:06:05
# 7          20       13.80      US  2022-08-31 23:06:06
# 8         100        3.00      MX  2022-08-31 23:06:06
# 9          97       17.49      PG  2022-08-31 23:06:07

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Fortuna      US  40.5982 -124.1573     69.93        79           0
# 1  Kruisfontein      ZA -34.0033   24.7314     53.89        81           0
# 2      Qui Nhon      VN  13.7667  109.2333     78.26        87           0
# 3          Zhob      PK  31.3411   69.4481     74.97        58           0
# 4        Barrow      US  71.2906 -156.7887     39.22        93         100
# 5       Qaanaaq      GL  77.4840  -69.3632     31.82        68           0
# 6      Thompson      CA  55.7435  -97.8558     57.43        47          98
# 7     Jamestown      US  42.0970  -79.2353     73.02        49          20
# 8    Miraflores      MX  19.2167  -98.8083     77.65        74         100
# 9       Kavieng      PG  -2.5744  150.7967     84.61        64          97
#
#    Wind Speed Current Description
# 0       13.80           clear sky
# 1        7.47           clear sky
# 2        4.21           clear sky
# 3        4.12           clear sky
# 4       23.02                mist
# 5        3.18           clear sky
# 6        3.40     overcast clouds
# 7       13.80          few clouds
# 8        3.00     overcast clouds
# 9       17.49     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = Path('Weather_Database/WeatherPy_Database.csv')
output_data_file.parent.mkdir(parents=True, exist_ok=True)
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
